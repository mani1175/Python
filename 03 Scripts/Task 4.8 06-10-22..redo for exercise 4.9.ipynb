# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
# Importing data set ords_prods_merged
path = r"C:\Users\ap101\INSTACART BASKET ANALYSIS"

# %%
df_ords_prods_merge = pd.read_pickle(r"C:\Users\ap101\INSTACART BASKET ANALYSIS\02 Data\Prepared Data\orders_products_merged_deriving_new_var.pkl")

# %%
# Create a subset for first 1 million entries
df = df_ords_prods_merge[:1000000]

# %%
df.shape
# Out:
# (1000000, 18)

# %%
df.head(10)
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0  2539329.0      1.0           1.0                 2.0                8.0
# 1  2398795.0      1.0           2.0                 3.0                7.0
# 2   473747.0      1.0           3.0                 3.0               12.0
# 3  2254736.0      1.0           4.0                 4.0                7.0
# 4   431534.0      1.0           5.0                 4.0               15.0
# 5  3367565.0      1.0           6.0                 2.0                7.0
# 6   550135.0      1.0           7.0                 1.0                9.0
# 7  3108588.0      1.0           8.0                 1.0               14.0
# 8  2295261.0      1.0           9.0                 1.0               16.0
# 9  2550362.0      1.0          10.0                 4.0                8.0
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN       196.0                1.0        0.0
# 1                    15.0       196.0                1.0        1.0
# 2                    21.0       196.0                1.0        1.0
# 3                    29.0       196.0                1.0        1.0
# 4                    28.0       196.0                1.0        1.0
# 5                    19.0       196.0                1.0        1.0
# 6                    20.0       196.0                1.0        1.0
# 7                    14.0       196.0                2.0        1.0
# 8                     0.0       196.0                4.0        1.0
# 9                    30.0       196.0                1.0        1.0
#
#   product_name  aisle_id  department_id  prices _merge    price_range_loc  \
# 0         Soda      77.0            7.0     9.0   both  Mid-range product
# 1         Soda      77.0            7.0     9.0   both  Mid-range product
# 2         Soda      77.0            7.0     9.0   both  Mid-range product
# 3         Soda      77.0            7.0     9.0   both  Mid-range product
# 4         Soda      77.0            7.0     9.0   both  Mid-range product
# 5         Soda      77.0            7.0     9.0   both  Mid-range product
# 6         Soda      77.0            7.0     9.0   both  Mid-range product
# 7         Soda      77.0            7.0     9.0   both  Mid-range product
# 8         Soda      77.0            7.0     9.0   both  Mid-range product
# 9         Soda      77.0            7.0     9.0   both  Mid-range product
#
#       busiest_day    Busiest_days busiest_period_of_day
# 0  Regularly busy  Regularly busy         Fewest orders
# 1  Regularly busy    Slowest days         Fewest orders
# 2  Regularly busy    Slowest days         Fewest orders
# 3      Least busy  Regularly busy         Fewest orders
# 4      Least busy  Regularly busy         Fewest orders
# 5  Regularly busy  Regularly busy         Fewest orders
# 6  Regularly busy  Regularly busy         Fewest orders
# 7  Regularly busy  Regularly busy         Fewest orders
# 8  Regularly busy  Regularly busy         Fewest orders
# 9      Least busy  Regularly busy         Fewest orders

# %%
df.groupby('product_name')

# %%
df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 4.0              19.315612
# 7.0              17.466053
# 13.0             17.753001
# 14.0             19.246334
# 16.0             19.463012
# 17.0             11.294069
# 19.0             21.234049

# %%
# Some aggregations can be conducted without use of agg() function
df.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 4.0     19.315612
# 7.0     17.466053
# 13.0    17.753001
# 14.0    19.246334
# 16.0    19.463012
# 17.0    11.294069
# 19.0    21.234049
# Name: order_number, dtype: float64

# %%
# Performing multiple aggregations
df.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean  min   max
# department_id
# 4.0              19.315612  1.0  99.0
# 7.0              17.466053  1.0  99.0
# 13.0             17.753001  1.0  99.0
# 14.0             19.246334  1.0  99.0
# 16.0             19.463012  1.0  99.0
# 17.0             11.294069  1.0  98.0
# 19.0             21.234049  1.0  99.0

# %%
df_ords_prods_merge['max_order'] = df_ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
df_ords_prods_merge.head(15)
# Out:
#      order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329.0      1.0           1.0                 2.0                8.0
# 1   2398795.0      1.0           2.0                 3.0                7.0
# 2    473747.0      1.0           3.0                 3.0               12.0
# 3   2254736.0      1.0           4.0                 4.0                7.0
# 4    431534.0      1.0           5.0                 4.0               15.0
# 5   3367565.0      1.0           6.0                 2.0                7.0
# 6    550135.0      1.0           7.0                 1.0                9.0
# 7   3108588.0      1.0           8.0                 1.0               14.0
# 8   2295261.0      1.0           9.0                 1.0               16.0
# 9   2550362.0      1.0          10.0                 4.0                8.0
# 10  2968173.0     15.0          15.0                 1.0                9.0
# 11  1870022.0     15.0          17.0                 2.0               16.0
# 12  1911383.0     15.0          18.0                 2.0               11.0
# 13  2715276.0     15.0          21.0                 1.0                9.0
# 14   487368.0     15.0          22.0                 1.0               10.0
#
#     days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                      NaN       196.0                1.0        0.0
# 1                     15.0       196.0                1.0        1.0
# 2                     21.0       196.0                1.0        1.0
# 3                     29.0       196.0                1.0        1.0
# 4                     28.0       196.0                1.0        1.0
# 5                     19.0       196.0                1.0        1.0
# 6                     20.0       196.0                1.0        1.0
# 7                     14.0       196.0                2.0        1.0
# 8                      0.0       196.0                4.0        1.0
# 9                     30.0       196.0                1.0        1.0
# 10                     7.0       196.0                2.0        0.0
# 11                     8.0       196.0                6.0        1.0
# 12                     7.0       196.0                1.0        1.0
# 13                     7.0       196.0                1.0        1.0
# 14                    14.0       196.0                1.0        1.0
#
#    product_name  aisle_id  department_id  prices _merge    price_range_loc  \
# 0          Soda      77.0            7.0     9.0   both  Mid-range product
# 1          Soda      77.0            7.0     9.0   both  Mid-range product
# 2          Soda      77.0            7.0     9.0   both  Mid-range product
# 3          Soda      77.0            7.0     9.0   both  Mid-range product
# 4          Soda      77.0            7.0     9.0   both  Mid-range product
# 5          Soda      77.0            7.0     9.0   both  Mid-range product
# 6          Soda      77.0            7.0     9.0   both  Mid-range product
# 7          Soda      77.0            7.0     9.0   both  Mid-range product
# 8          Soda      77.0            7.0     9.0   both  Mid-range product
# 9          Soda      77.0            7.0     9.0   both  Mid-range product
# 10         Soda      77.0            7.0     9.0   both  Mid-range product
# 11         Soda      77.0            7.0     9.0   both  Mid-range product
# 12         Soda      77.0            7.0     9.0   both  Mid-range product
# 13         Soda      77.0            7.0     9.0   both  Mid-range product
# 14         Soda      77.0            7.0     9.0   both  Mid-range product
#
#        busiest_day    Busiest_days busiest_period_of_day  max_order
# 0   Regularly busy  Regularly busy         Fewest orders       11.0
# 1   Regularly busy    Slowest days         Fewest orders       11.0
# 2   Regularly busy    Slowest days         Fewest orders       11.0
# 3       Least busy  Regularly busy         Fewest orders       11.0
# 4       Least busy  Regularly busy         Fewest orders       11.0
# 5   Regularly busy  Regularly busy         Fewest orders       11.0
# 6   Regularly busy  Regularly busy         Fewest orders       11.0
# 7   Regularly busy  Regularly busy         Fewest orders       11.0
# 8   Regularly busy  Regularly busy         Fewest orders       11.0
# 9       Least busy  Regularly busy         Fewest orders       11.0
# 10  Regularly busy  Regularly busy         Fewest orders       23.0
# 11  Regularly busy  Regularly busy         Fewest orders       23.0
# 12  Regularly busy  Regularly busy         Fewest orders       23.0
# 13  Regularly busy  Regularly busy         Fewest orders       23.0
# 14  Regularly busy  Regularly busy           Most orders       23.0

# %%
df_ords_prods_merge.head(100)
# Out:
#      order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329.0      1.0           1.0                 2.0                8.0
# 1   2398795.0      1.0           2.0                 3.0                7.0
# 2    473747.0      1.0           3.0                 3.0               12.0
# 3   2254736.0      1.0           4.0                 4.0                7.0
# 4    431534.0      1.0           5.0                 4.0               15.0
# ..        ...      ...           ...                 ...                ...
# 95  3226575.0    360.0           1.0                 5.0               12.0
# 96  1469869.0    377.0           3.0                 5.0               17.0
# 97  1927023.0    387.0           2.0                 4.0               10.0
# 98   858092.0    420.0           4.0                 1.0               19.0
# 99   119314.0    420.0           5.0                 3.0               19.0
#
#     days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                      NaN       196.0                1.0        0.0
# 1                     15.0       196.0                1.0        1.0
# 2                     21.0       196.0                1.0        1.0
# 3                     29.0       196.0                1.0        1.0
# 4                     28.0       196.0                1.0        1.0
# ..                     ...         ...                ...        ...
# 95                     NaN       196.0                1.0        0.0
# 96                     3.0       196.0                9.0        0.0
# 97                    22.0       196.0                3.0        0.0
# 98                    30.0       196.0                2.0        0.0
# 99                    16.0       196.0                2.0        1.0
#
#    product_name  aisle_id  department_id  prices _merge    price_range_loc  \
# 0          Soda      77.0            7.0     9.0   both  Mid-range product
# 1          Soda      77.0            7.0     9.0   both  Mid-range product
# 2          Soda      77.0            7.0     9.0   both  Mid-range product
# 3          Soda      77.0            7.0     9.0   both  Mid-range product
# 4          Soda      77.0            7.0     9.0   both  Mid-range product
# ..          ...       ...            ...     ...    ...                ...
# 95         Soda      77.0            7.0     9.0   both  Mid-range product
# 96         Soda      77.0            7.0     9.0   both  Mid-range product
# 97         Soda      77.0            7.0     9.0   both  Mid-range product
# 98         Soda      77.0            7.0     9.0   both  Mid-range product
# 99         Soda      77.0            7.0     9.0   both  Mid-range product
#
#        busiest_day    Busiest_days busiest_period_of_day  max_order
# 0   Regularly busy  Regularly busy         Fewest orders       11.0
# 1   Regularly busy    Slowest days         Fewest orders       11.0
# 2   Regularly busy    Slowest days         Fewest orders       11.0
# 3       Least busy  Regularly busy         Fewest orders       11.0
# 4       Least busy  Regularly busy         Fewest orders       11.0
# ..             ...             ...                   ...        ...
# 95  Regularly busy  Regularly busy         Fewest orders        4.0
# 96  Regularly busy  Regularly busy         Fewest orders        4.0
# 97      Least busy  Regularly busy           Most orders        9.0
# 98  Regularly busy  Regularly busy         Fewest orders       23.0
# 99  Regularly busy    Slowest days         Fewest orders       23.0
#
# [100 rows x 19 columns]

# %%
pd.options.display.max_rows = None

# %%
# Create flag that assigns "loyalty" label to user ID based on corresponding max order value
df_ords_prods_merge.loc[df_ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'
df_ords_prods_merge.loc[(df_ords_prods_merge['max_order'] <= 40) & (df_ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'
df_ords_prods_merge.loc[df_ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
df_ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# Regular customer    16381472
# Loyal customer      10679578
# New customer         5580218
# NaN                       11
# Name: loyalty_flag, dtype: int64

# %%
df_ords_prods_merge[['user_id', 'loyalty_flag', 'order_number']].head(60)
# Out:
#     user_id      loyalty_flag  order_number
# 0       1.0  Regular customer           1.0
# 1       1.0  Regular customer           2.0
# 2       1.0  Regular customer           3.0
# 3       1.0  Regular customer           4.0
# 4       1.0  Regular customer           5.0
# 5       1.0  Regular customer           6.0
# 6       1.0  Regular customer           7.0
# 7       1.0  Regular customer           8.0
# 8       1.0  Regular customer           9.0
# 9       1.0  Regular customer          10.0
# 10     15.0  Regular customer          15.0
# 11     15.0  Regular customer          17.0
# 12     15.0  Regular customer          18.0
# 13     15.0  Regular customer          21.0
# 14     15.0  Regular customer          22.0
# 15     19.0      New customer           2.0
# 16     19.0      New customer           5.0
# 17     19.0      New customer           7.0
# 18     21.0  Regular customer          10.0
# 19     31.0  Regular customer          10.0
# 20     31.0  Regular customer          17.0
# 21     43.0  Regular customer           6.0
# 22     43.0  Regular customer           9.0
# 23     52.0  Regular customer           1.0
# 24     52.0  Regular customer           2.0
# 25     52.0  Regular customer           3.0
# 26     52.0  Regular customer           5.0
# 27     52.0  Regular customer           7.0
# 28     52.0  Regular customer           9.0
# 29     52.0  Regular customer          10.0
# 30     52.0  Regular customer          11.0
# 31     52.0  Regular customer          12.0
# 32     52.0  Regular customer          15.0
# 33     52.0  Regular customer          17.0
# 34     52.0  Regular customer          18.0
# 35     52.0  Regular customer          19.0
# 36     52.0  Regular customer          21.0
# 37     67.0  Regular customer           1.0
# 38     67.0  Regular customer           2.0
# 39     67.0  Regular customer           3.0
# 40     67.0  Regular customer           4.0
# 41     67.0  Regular customer           5.0
# 42     67.0  Regular customer           6.0
# 43     67.0  Regular customer           8.0
# 44     67.0  Regular customer           9.0
# 45     67.0  Regular customer          10.0
# 46     67.0  Regular customer          11.0
# 47     67.0  Regular customer          12.0
# 48     67.0  Regular customer          13.0
# 49     67.0  Regular customer          14.0
# 50     67.0  Regular customer          16.0
# 51     67.0  Regular customer          18.0
# 52     67.0  Regular customer          19.0
# 53     67.0  Regular customer          21.0
# 54     67.0  Regular customer          22.0
# 55     67.0  Regular customer          23.0
# 56     81.0      New customer           3.0
# 57     81.0      New customer           5.0
# 58     82.0  Regular customer           1.0
# 59     82.0  Regular customer           3.0

# %%
df_ords_prods_merge.to_pickle(os.path.join(path, '02 Data','Prepared Data', '4.8_ords_prods_merge.pkl'))
