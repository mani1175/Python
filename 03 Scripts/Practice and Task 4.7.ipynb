# %% [raw]
# # Importing libraries
# import pandas as pd
# import numpy as np
# import os

# %%
# Importing data set ords_prods_merged
path = r"C:\Users\ap101\INSTACART BASKET ANALYSIS"

# %%
df_ords_prods_merge = pd.read_pickle(r"C:\Users\ap101\INSTACART BASKET ANALYSIS\02 Data\Prepared Data\orders_products_merged.pkl")

# %%
# Create a subset for the 1st million rows
df = df_ords_prods_merge[:1000000]

# %%
# Confirms there are a million rows in the dataframe
df.shape
# Out:
# (1000000, 14)

# %%
def price_label(row):

  if row['prices'] <= 5:
    return 'Low-range product'
  elif (row['prices'] > 5) and (row['prices'] <= 15):
    return 'Mid-range product'
  elif row['prices'] > 15:
    return 'High range product'
  else: return 'not enough data'

# %% [markdown]
# The above function is a function your creating yourself, so you need to start by "defining" it. Use "def" syntax for defining and follow it by the name you want to give your new function (in this case 'price_label'). The "row" in parenthesis is a standard argument telling the function to look into each row in the dataframe

# %% [markdown]
# Elif function stands for "else if"

# %%
# Define price_label function and apply it to subset created
df['price_range'] = df.apply(price_label, axis=1)
# Out:
# C:\Users\ap101\AppData\Local\Temp\ipykernel_9940\1503704886.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range'] = df.apply(price_label, axis=1)

# %%
# What is the most expensive product within the subset?
# Can be done using the max() function
df['prices'].max()
# Out:
# 14.0

# %%
# If-Statements with the loc () function
df.loc[df['prices'] > 15, 'price_range_loc'] = 'High range product'

# %%
df['price_range_loc'].value_counts(dropna = False)
# Out:
# Mid range product    581197
# Low range product    212594
# NaN                  206209
# Name: price_range_loc, dtype: int64

# %%
# Repeating the process again, this time on your entire dataframe
df_ords_prods_merge.loc[df_ords_prods_merge['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
df_ords_prods_merge.loc[(df_ords_prods_merge['prices'] <= 15) & (df_ords_prods_merge['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df_ords_prods_merge.loc[df_ords_prods_merge['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
df_ords_prods_merge['price_range_loc'].value_counts(dropna = False)
# Out:
# Mid-range product     21860868
# Low-range product     10126324
# High-range product      417678
# NaN                     236409
# Name: price_range_loc, dtype: int64

# %% [markdown]
# # If statments with for-loops

# %%
df_ords_prods_merge['orders_day_of_week'].value_counts(dropna = False)
# Out:
# 0.0    6252941
# 1.0    5696724
# 6.0    4530304
# 2.0    4243173
# 5.0    4236989
# 3.0    3868747
# 4.0    3812390
# NaN         11
# Name: orders_day_of_week, dtype: int64

# %%
result = []

for value in df_ords_prods_merge["orders_day_of_week"]:
  if value == 0:
    result.append("Busiest day")
  elif value == 4:
    result.append("Least busy")
  else:
    result.append("Regularly busy")

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %%
df_ords_prods_merge['busiest_day'] = result

# %%
df_ords_prods_merge['busiest_day'].value_counts(dropna = False)
# Out:
# Regularly busy    22575948
# Busiest day        6252941
# Least busy         3812390
# Name: busiest_day, dtype: int64

# %% [markdown]
# # Task

# %% [markdown]
# 1. If you haven't done so already, complete the instructions in the Exercise for creating the "price_label" and "busiest_day" columns

# %% [markdown]
# 2. Suppose your clients have changed thier minds about the labels you created in your "busiest_day" column. Now, they want "Busiest day" to become "Busiest days" This label should correspond with the 2 busiest days of the week as opposed to the single busiest day. At the same time, they'd also like to know the 2 slowest days. Create a column for this using a suitable method

# %%
df_ords_prods_merge['orders_day_of_week'].value_counts(dropna = False)
# Out:
# 0.0    6252941
# 1.0    5696724
# 6.0    4530304
# 2.0    4243173
# 5.0    4236989
# 3.0    3868747
# 4.0    3812390
# NaN         11
# Name: orders_day_of_week, dtype: int64

# %%
result = []

for value in df_ords_prods_merge["orders_day_of_week"]:
  if value == 0 and 1:
    result.append("Busiest day")
  elif value == 3 and 4:
    result.append("Slowest days")
  else:
    result.append("Regularly busy")

# %%
result
# Out:
# ['Regularly busy',
#  'Slowest days',
#  'Slowest days',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Slowest days',
#  'Regularly busy',
#  'Slowest days',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Slowest days',
#  'Slowest days',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %%
df_ords_prods_merge['Busiest_days'] = result

# %%
df_ords_prods_merge['Busiest_days'].value_counts(dropna = False)
# Out:
# Regularly busy    22519591
# Busiest day        6252941
# Slowest days       3868747
# Name: Busiest_days, dtype: int64

# %% [markdown]
# 4. When too many users make Instacart orders at the same time, the app freezes. The senior technical officer at Instacart wants you to identify the busiest hours of the day. Rather than by hour, they want periods of time labeled "Most orders", "Average orders", and "Fewest orders". Create a column containing these labels called "Busiest_period_of_day"

# %%
df_ords_prods_merge['order_hour_of_day'].value_counts(dropna = False)
# Out:
# 10.0    2781009
# 11.0    2755369
# 14.0    2709084
# 15.0    2682090
# 13.0    2680171
# 12.0    2637533
# 16.0    2554110
# 9.0     2471067
# 17.0    2104225
# 8.0     1729871
# 18.0    1649870
# 19.0    1268365
# 20.0     983232
# 7.0      897163
# 21.0     801052
# 22.0     638671
# 23.0     405051
# 6.0      292533
# 0.0      220337
# 1.0      116589
# 5.0       88661
# 2.0       69904
# 4.0       53636
# 3.0       51675
# NaN          11
# Name: order_hour_of_day, dtype: int64

# %%
result = []

for value in df_ords_prods_merge["order_hour_of_day"]:
  if value == 10:
    result.append("Most orders")
  elif value == 13:
    result.append("Average orders")
  else:
    result.append("Fewest orders")

# %%
result
# Out:
# ['Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Most orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Most orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Most orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Most orders',
#  'Most orders',
#  'Fewest orders',
#  'Most orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Average orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Most orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Most orders',
#  'Fewest orders',
#  'Most orders',
# ...

# %%
# Create new column titled "Busiest_period_of_day"
df_ords_prods_merge['busiest_period_of_day'] = result

# %%
df_ords_prods_merge['busiest_period_of_day'].value_counts(dropna = False)
# Out:
# Fewest orders     27180099
# Most orders        2781009
# Average orders     2680171
# Name: busiest_period_of_day, dtype: int64

# %%
df_ords_prods_merge.head()
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0  2539329.0      1.0           1.0                 2.0                8.0
# 1  2398795.0      1.0           2.0                 3.0                7.0
# 2   473747.0      1.0           3.0                 3.0               12.0
# 3  2254736.0      1.0           4.0                 4.0                7.0
# 4   431534.0      1.0           5.0                 4.0               15.0
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN       196.0                1.0        0.0
# 1                    15.0       196.0                1.0        1.0
# 2                    21.0       196.0                1.0        1.0
# 3                    29.0       196.0                1.0        1.0
# 4                    28.0       196.0                1.0        1.0
#
#   product_name  aisle_id  department_id  prices _merge    price_range_loc  \
# ...

# %% [markdown]
# 5. Print the frequency for this new column

# %%
df_ords_prods_merge['busiest_period_of_day']
# Out:
# 0           Fewest orders
# 1           Fewest orders
# 2           Fewest orders
# 3           Fewest orders
# 4           Fewest orders
#                 ...
# 32641274    Fewest orders
# 32641275    Fewest orders
# 32641276    Fewest orders
# 32641277    Fewest orders
# 32641278    Fewest orders
# Name: busiest_period_of_day, Length: 32641279, dtype: object

# %%
df_ords_prods_merge.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_merged_deriving_new_var.pkl'))
